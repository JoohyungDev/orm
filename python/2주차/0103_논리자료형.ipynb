# %% [markdown]
# # 1. 논리 자료형이란?

# %% [markdown]
# 수학과 컴퓨터 과학에서 논리 자료형은 값으로 True와 False를 가지는 자료형을 말합니다. bool과 boolean이라고 불리는데 어떤 개념에서 가져온 이름이 아니라 수학자 조지 불(George Boole)이름에서 따온 것입니다. 파이썬에서는 이를 bool 타입이라고 부릅니다. 논리 자료형은 조건문, 반복문, 논리 연산 등 다양한 상황에서 사용되며, 프로그램의 흐름을 제어하는 데 중요한 역할을 합니다.

# %%
# True = 1 = 참
# False = 0 = 거짓
