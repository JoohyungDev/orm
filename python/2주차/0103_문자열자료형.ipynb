# %% [markdown]
# # 1. 문자열 자료형

# %% [markdown]
# - 문자열 자료형은 열이 붙어있어요. 시퀀스형 자료형이라고도 합니다.

# %%
# 문자열 생성은 작은 따옴표 혹은 큰따옴표(내규를 따름)
x = "hello"
y = 'python'

# %%
print(x, y)
# Out:
# hello python

# %%
print(type(x), type(y))
# Out:
# <class 'str'> <class 'str'>

# %%
i = '''안녕하세요.
박주형입니다.
파이썬 좋아요.
반가워요.
'''

# %%
print(i)
# Out:
# 안녕하세요.
# 박주형입니다.
# 파이썬 좋아요.
# 반가워요.

# %% [markdown]
# # 2.1 문자열 덧셈 곱셈

# %%
x = 'hello'
y = 'world'
print(x + y)
# Out:
# helloworld

# %%
print(x * 3)
# Out:
# hellohellohello

# %% [markdown]
# # 2.2 문자열 인덱싱

# %%
s = '위니브 월드'
print(s[0])
print(s[-1])
# Out:
# 위
# 드

# %% [markdown]
# # 2.3 문자열 슬라이싱

# %% [markdown]
# ## 2.3.1 슬라이싱

# %%
# [start:stop:step]

s = '위니브 월드 외곽'

print(s[5:])
# Out:
# 드 외곽

# %%
# 다양한 슬라이싱

# 전체 출력
print(s[:])
# 거꾸로 출력
print(s[::-1])
# 2칸씩 출력
print(s[::2])
# Out:
# 위니브 월드 외곽
# 곽외 드월 브니위
# 위브월 곽

# %%
# 확장자 잘라서 출력
s = 'weniv_licat.png'
print(s[:-4])
# Out:
# weniv_licat

# %%
# 확장자만 출력
s = 'weniv_licat.png'
print(s[-3:])
# Out:
# png

# %%
print(s[-1:-4])

# %%
# 슬라이스 복사 - 다만 ID가 달라짐
s = [1, 2, 3]
ss = s[:]

print(id(s), id(ss))
# Out:
# 136241647626048 136241647616256

# %% [markdown]
# # 3. 문자열 메서드

# %% [markdown]
# ## 3.1 lower(), upper()

# %%
# 소문자 -> 대문자 혹은 그 반대
s = 'weniv CEO licat'

print(s.lower())
print(s.upper())
# Out:
# weniv ceo licat
# WENIV CEO LICAT

# %% [markdown]
# ## 3.2 find() / index()

# %% [markdown]
# - 찾을 수 없는 문자열의 경우 find는 -1, index는 error를 반환함

# %%
s = 'weniv CEO licat'
s.find('CEO')
s.index('CTO')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-67274116d3f8> in <cell line: 3>()
#       1 s = 'weniv CEO licat'
#       2 s.find('CEO')
# ----> 3 s.index('CTO')
#
# ValueError: substring not found

# %% [markdown]
# ## 3.3 count()

# %% [markdown]
# - count()는 특정 문자열이나 숫자의 개수를 셀 때 사용함

# %%
# 공백, 대/소문자 구분 등 일치만하면 다 찾아줌
s = 'weniv CEO licat'
s.count('d')
# Out:
# 0

# %% [markdown]
# ## 3.4 strip()

# %% [markdown]
# - 문자열 양쪽의 공백 제거해주는 메서드

# %%
s = '   weniv CEO licat   '
s.strip()
# Out:
# 'weniv CEO licat'

# %%
'    ,!!  hello world   '.strip(' ,!')
#양쪽의 공백과 ',!'을 제거해주는 method
# Out:
# 'hello world'

# %% [markdown]
# ## 3.5 replace()

# %% [markdown]
# - 문자열 중 특정 문자열을 찾아 다른 문자열로 대체하고 싶은 경우 사용

# %%
s = 'weniv CEO licat'
s.replace('CEO', 'CTO') #원하는 문자열을 다른 문자열로 대체할 때 사용하는 method
# Out:
# 'weniv CTO licat'

# %% [markdown]
# 다만 수정된 문자열이 원본에 적용되지 않음

# %%
s = 'weniv CEO licat'
ss = s.replace('i', 'I')
ss, s # 출력: ('weniv CEO licat', 'wenIv CEO lIcat')
# Out:
# ('wenIv CEO lIcat', 'weniv CEO licat')

# %% [markdown]
# ## 3.6 split() / join()

# %% [markdown]
# - 문자열을 합치고 나누는 메서드
#
# - 출력은 리스트 형태로 결과가 나옴

# %%
s = 'weniv CEO licat'
s.split() #공백을 기준으로 문자열 나누기
# Out:
# ['weniv', 'CEO', 'licat']

# %%
s = 'weniv-CEO-licat'
s.split('-') #-을 기준으로 문자열 나누기
# Out:
# ['weniv', 'CEO', 'licat']

# %%
s = ['weniv', 'CEO', 'licat']
'-'.join(s) #리스트를 하나의 문자열로 합치기
# Out:
# 'weniv-CEO-licat'

# %% [markdown]
# ## 3.7 format()

# %% [markdown]
# - 문자열 내에 변수의 값을 대입할 때 사용하는 메서드

# %%
name = 'licat'
age = 29

print('제 이름은 {}이고, 나이는 {}살입니다.'.format(name, age))
# Out:
# 제 이름은 licat이고, 나이는 29살입니다.

# %% [markdown]
# ## 3.8 isalnum( ) / isdigit( ) / isalpha( ) / isascii( )

# %% [markdown]
# - 문자열이 숫자로만 이루어져있는지 알파벳인지 등을 확인 가능

# %% [markdown]
# ## 3.9 rjust() / ljust() / center()

# %%
# rjust( ) 메서드는 문자열을 지정한 길이로 맞추고, 왼쪽을 지정한 문자로 채우는 메서드입니다. 아래 예제를 살펴보겠습니다.
s = 'licat'
s.rjust(10, '-') #문자열을 지정한 길이로 맞추고, 왼쪽을 '-'로 채우는 method
# Out:
# '-----licat'

# %%
# ljust( ) 메서드는 문자열을 지정한 길이로 맞추고, 오른쪽을 지정한 문자로 채우는 메서드입니다. 아래 예제를 살펴보겠습니다.
s = 'licat'
s.ljust(10, '-') #문자열을 지정한 길이로 맞추고, 오른쪽을 '-'로 채우는 method
# Out:
# 'licat-----'

# %%
# center( ) 메서드는 문자열을 지정한 길이로 맞추고, 양쪽을 지정한 문자로 채우는 메서드입니다. 아래 예제를 살펴보겠습니다.
s = 'licat'
s.center(11, '-') #문자열을 지정한 길이로 맞추고, 양쪽을 '-'로 채우는 method
# Out:
# '---licat---'

# %%
s = '459432-1'
s.ljust(14, '*')
# Out:
# '459432-1******'

# %% [markdown]
# ## 3.10 zfill()

# %% [markdown]
# - 문자열의 zfill() 메서드는 주어진 길이만큼 문자열의 앞쪽을 '0'으로 채워서 반환합니다. 이 메서드는 숫자를 포함한 문자열에서 자릿수를 일정하게 유지할 때 유용하게 사용됩니다.

# %%
x = "42"
result = x.zfill(5)
print(result)  # 00042
# Out:
# 00042

# %%
y = "-42"
result = y.zfill(5)
print(result)  # -0042
# Out:
# -0042

# %%
z = "abc"
result = z.zfill(5)
print(result)  # 00abc
# Out:
# 00abc

# %%
filename = '1'.zfill(3) + ".jpg"
print(filename)
# Out:
# 001.jpg

# %%
년 = '23'
월 = '9'
일 = '8'
오늘날짜 = 년 + 월 + 일
print(오늘날짜)
오늘날짜 = 년 + 월.zfill(2) + 일.zfill(2)
print(오늘날짜)
# Out:
# 2398
# 230908

# %% [markdown]
# ## 3.10 translate()

# %% [markdown]
# - translate() 메서드는 문자열 내의 특정 문자들을 다른 문자로 치환하거나 제거할 때 사용합니다.
# - replace와 다르게 한 번에 많은 문자열들을 원하는 문자로 치환할 수 있습니다.

# %%
# 변환 테이블 생성
table = str.maketrans("abc", "123")

# %% [markdown]
# 이 예제는 'a'는 '1'로, 'b'는 '2'로, 'c'는 '3'로 변환하겠다는 뜻입니다.

# %%
text = "abcde"
result = text.translate(table)
print(result)  # 123de
# Out:
# 123de

# %% [markdown]
# - translate() 메서드는 특정 문자를 제거하는 데도 사용될 수 있습니다. 이를 위해서는 str.maketrans()의 세 번째 인수로 제거할 문자를 지정합니다.

# %%
# 'd'와 'e' 문자 제거하기
table = str.maketrans('', '', 'de')
text = "abcde"
result = text.translate(table)
print(result)  # abc
# Out:
# abc

# %%
table = str.maketrans('\n\t', '  ') # 똑같은 길이를 가지고 있어야 함
'weniv \n\n\n CEO \t\t\t licat'.translate(table)
# Out:
# 'weniv     CEO     licat'

# %% [markdown]
# translate() 메서드는 특히 텍스트 데이터를 처리하는 곳에서 많이 사용될 수 있습니다. 예를 들어, 텍스트 내의 특정 문자나 기호를 제거하거나 다른 문자로 치환하려 할 때 이 메서드를 활용할 수 있습니다.

# %% [markdown]
# # 4. 이스케이프 문자

# %% [markdown]
# - `\n`: 새로운 줄(줄바꿈)을 나타냅니다.
# - `\t`: 탭 문자를 나타냅니다.
# - `\r`: 커서를 현재 줄의 처음으로 이동합니다.
# - `\"`: 큰따옴표를 나타냅니다.
# - `\'`: 작은따옴표를 나타냅니다.
# - `\\`: 백슬래시를 나타냅니다.

# %%
print("Hello\nWorld!") # Hello와 World! 사이에 줄바꿈이 일어납니다.
print("Hello\tWorld!") # Hello와 World! 사이에 탭 간격이 생깁니다.
print("She said, \"Hello World!\"") # 큰따옴표 내부에 문자열을 출력합니다.
print('She said, \'Hello World!\'') # 작은따옴표 내부에 문자열을 출력합니다.
print("Backslash: \\") # 백슬래시를 출력합니다.
# Out:
# Hello
# World!
# Hello	World!
# She said, "Hello World!"
# She said, 'Hello World!'
# Backslash: \
